# %%
# %load_ext autoreload
# %autoreload 2

from multiOrbKondoRGFlow import *
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

K_MIN = 0
K_MAX = 2 * np.pi
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
size = 1000
k_1Darr = np.linspace(K_MIN, K_MAX, size)
kx_arr, ky_arr = np.meshgrid(k_1Darr, k_1Darr)
dispersion = tightBindDispersion(size, 1)
# print(np.round(dispersion.flatten(), 1))
points = getIsoEnergeticContour(dispersion.flatten(), 0)

# %%
# plt.imshow(Ek)
# plt.colorbar()
# plt.show()
plt.imshow(np.log10(dos))
plt.colorbar()

# %%
size = 2000
k_1Darr = np.linspace(K_MIN, K_MAX, size)
kx_arr, ky_arr = np.meshgrid(k_1Darr, k_1Darr)
dispersion = tightBindDispersion(kx_arr, ky_arr, 1)
# print(np.round(dispersion.flatten(), 1))
points = getIsoEnergeticContour(dispersion.flatten(), 0)
# plt.imshow(dispersion, extent=(K_MIN, K_MAX, K_MIN, K_MAX))

# for point in tqdm(points):
#     kx, ky = map1Dto2D(point, size)
#     plt.scatter(k_1Darr[kx], k_1Darr[ky], color='b', s=1)

# %%
kondoCoupArray = main({"size_half": 10, "hop_t": 1, "kondoCoup": 10, "bathIntCoup": -1, "orbital": "p"})
print("hi")
# for i in [0, 5, 8, 10]:
#     plt.imshow(np.reshape(kondoCoupArray[i][830], (41, 41)), interpolation='None')
#     plt.colorbar()
#     plt.show()
# Out:
# ...
#  80%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                              | 8/10 [00:37<00:08,  4.28s/it]/home/kirito/storage/work/TilingProject/dwaveNumerics/multiOrbKondoRGFlow.py:104: RuntimeWarning: overflow encountered in multiply
#   (
# /home/kirito/storage/work/TilingProject/dwaveNumerics/multiOrbKondoRGFlow.py:111: RuntimeWarning: overflow encountered in scalar multiply
#   )
# /home/kirito/storage/work/TilingProject/dwaveNumerics/multiOrbKondoRGFlow.py:104: RuntimeWarning: overflow encountered in multiply
#   (
# /home/kirito/storage/work/TilingProject/dwaveNumerics/multiOrbKondoRGFlow.py:102: RuntimeWarning: overflow encountered in multiply
#   args["dOfStates"][UVPoints]
# /home/kirito/storage/work/TilingProject/dwaveNumerics/multiOrbKondoRGFlow.py:111: RuntimeWarning: overflow encountered in scalar multiply
#   )
# ...
